# %%
# Importing sagemaker will throw a ContextualVersionConflict due to site-packages containing
# two versions of urllib3. Even though the right urllib3 version (1.23) is active, we need to
# manually remove urllib3 1.25.3 & restart kernel to make sagemaker work.
# This could probably be moved to post_setup.sh, but leaving it here in case someone knows
# of a solution

import urllib3
assert(urllib3.__version__ == '1.23')

# !sudo rm -rf /opt/miniconda/envs/py3/lib/python3.6/site-packages/urllib3-1.25.3.dist-info

# %%
import os
import datetime

import boto3
import sagemaker
from sagemaker.tensorflow import TensorFlow
import tensorflow

from config import DATASET_URL, IMAGE_NAME, IAM_ROLE, MODEL_URL_PREFIX

# %%
training_sample_count = 60000  # Standard size of training data for MNIST
batch_size = 64
num_epochs = 10

training_step_count = int(training_sample_count * num_epochs / batch_size)

entry_point = 'model.py'
timestamp = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
output_path   = f"{MODEL_URL_PREFIX}{timestamp}/output"
code_location = f"{MODEL_URL_PREFIX}{timestamp}/code"

boto_session = boto3.Session(region_name="us-east-1",
                             aws_access_key_id=os.environ.get("AWS_ACCESS_KEY_ID_PROD"),
                             aws_secret_access_key=os.environ.get("AWS_SECRET_ACCESS_KEY_PROD"))

kwargs = dict(entry_point=entry_point,
              image_name=IMAGE_NAME,
              role=IAM_ROLE,
              sagemaker_session=sagemaker.Session(boto_session=boto_session),
              train_instance_count=1,
              train_instance_type='ml.m5.xlarge',
              framework_version='1.13',
              hyperparameters={'dataset-url': DATASET_URL,
                               'training_steps': training_step_count,
                               'batch_size': batch_size,
                               'evaluation_steps': 10,},
              py_version = 'py3',
              output_path = output_path,
              code_location=code_location,
              distributions={'parameter_server': {'enabled': True}})

# %% [markdown]
# # Training on a single sagemaker instance

# %%
mnist_estimator = TensorFlow(**kwargs)
# %time  mnist_estimator.fit(inputs=None)  # we're bypassing the conventional sagemaker input methods
# Out:
# 2019-07-02 18:43:48 Starting - Starting the training job...
# 2019-07-02 18:43:50 Starting - Launching requested ML instances......
# 2019-07-02 18:44:50 Starting - Preparing the instances for training...
# 2019-07-02 18:45:49 Downloading - Downloading input data
# 2019-07-02 18:45:49 Training - Downloading the training image......
# 2019-07-02 18:46:47 Training - Training image download completed. Training in progress..
# 2019-07-02 18:46:50,617 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2019-07-02 18:46:50,623 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-07-02 18:46:50,966 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-07-02 18:46:50,981 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-07-02 18:46:50,991 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch_size": 64,
#         "evaluation_steps": 10,
#         "dataset-url": "s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/",
#         "model_dir": "s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model",
#         "training_steps": 9375
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "petastorm-sagemaker-2019-07-02-18-43-48-315",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/code/petastorm-sagemaker-2019-07-02-18-43-48-315/source/sourcedir.tar.gz",
#     "module_name": "model",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "model.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":64,"dataset-url":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/","evaluation_steps":10,"model_dir":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model","training_steps":9375}
# SM_USER_ENTRY_POINT=model.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=model
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/code/petastorm-sagemaker-2019-07-02-18-43-48-315/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch_size":64,"dataset-url":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/","evaluation_steps":10,"model_dir":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model","training_steps":9375},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"petastorm-sagemaker-2019-07-02-18-43-48-315","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/code/petastorm-sagemaker-2019-07-02-18-43-48-315/source/sourcedir.tar.gz","module_name":"model","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"model.py"}
# SM_USER_ARGS=["--batch_size","64","--dataset-url","s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/","--evaluation_steps","10","--model_dir","s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model","--training_steps","9375"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_BATCH_SIZE=64
# SM_HP_EVALUATION_STEPS=10
# SM_HP_DATASET-URL=s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/
# SM_HP_MODEL_DIR=s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model
# SM_HP_TRAINING_STEPS=9375
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python model.py --batch_size 64 --dataset-url s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/ --evaluation_steps 10 --model_dir s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model --training_steps 9375
#
#
# Launch tensorboard by running the following in terminal:
# aws s3 sync {model_dir_parent_path} ~/Downloads/{model_dir_parent} && tensorboard --logdir=~/Downloads/{model_dir_parent}
# 2019-07-02 18:46:52,550 - tensorflow - INFO - Using config: {'_model_dir': 's3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model', '_tf_random_seed': None, '_save_summary_steps': 50, '_save_checkpoints_steps': 500, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f4c8f891c18>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# Inside training script on worker with (0-based) index 0 out of 0.
# 2019-07-02 18:46:52,976 - tensorflow - INFO - Not using Distribute Coordinator.
# 2019-07-02 18:46:52,977 - tensorflow - INFO - Running training and evaluation locally (non-distributed).
# 2019-07-02 18:46:52,979 - tensorflow - INFO - Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 500 or save_checkpoints_secs None.
# 2019-07-02 18:46:53.069602: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:46:53.070265: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:47:01,323 - tensorflow - WARNING - From model.py:84: map_and_batch (from tensorflow.contrib.data.python.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.experimental.map_and_batch(...)`.
# 2019-07-02 18:47:01,343 - tensorflow - INFO - Calling model_fn.
# 2019-07-02 18:47:01,804 - tensorflow - INFO - Done calling model_fn.
# 2019-07-02 18:47:01,806 - tensorflow - INFO - Create CheckpointSaverHook.
# 2019-07-02 18:47:01.842278: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:47:01.842335: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:47:01.880407: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:47:01.880461: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:47:01.900579: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:47:01.900616: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:47:02.088180: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:47:02.088226: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:47:02.138277: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:47:02.138321: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:47:02,594 - tensorflow - INFO - Graph was finalized.
# 2019-07-02 18:47:02.608864: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:47:02.608899: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:47:02,720 - tensorflow - INFO - Running local_init_op.
# 2019-07-02 18:47:02,726 - tensorflow - INFO - Done running local_init_op.
# 2019-07-02 18:47:02.778688: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:47:02.778737: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:47:03,238 - tensorflow - INFO - Saving checkpoints for 0 into s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt.
# 2019-07-02 18:47:04.521310: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:47:04.521347: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:47:04,865 - tensorflow - INFO - loss = 87.202965, step = 1
# 2019-07-02 18:47:07,712 - tensorflow - INFO - global_step/sec: 35.1168
# 2019-07-02 18:47:07,714 - tensorflow - INFO - loss = 2.03685, step = 101 (2.849 sec)
# 2019-07-02 18:47:11,449 - tensorflow - INFO - global_step/sec: 26.7615
# 2019-07-02 18:47:11,451 - tensorflow - INFO - loss = 1.7797443, step = 201 (3.738 sec)
# 2019-07-02 18:47:15,286 - tensorflow - INFO - global_step/sec: 26.0615
# 2019-07-02 18:47:15,287 - tensorflow - INFO - loss = 1.1699357, step = 301 (3.836 sec)
# 2019-07-02 18:47:18,463 - tensorflow - INFO - global_step/sec: 31.4772
# 2019-07-02 18:47:18,464 - tensorflow - INFO - loss = 0.99785733, step = 401 (3.177 sec)
# 2019-07-02 18:47:22,117 - tensorflow - INFO - Saving checkpoints for 500 into s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt.
# 2019-07-02 18:47:23.440767: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:47:23.440810: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:47:23,824 - tensorflow - INFO - Calling model_fn.
# 2019-07-02 18:47:23,969 - tensorflow - INFO - Done calling model_fn.
# 2019-07-02 18:47:23,993 - tensorflow - INFO - Starting evaluation at 2019-07-02-18:47:23
# 2019-07-02 18:47:24,093 - tensorflow - INFO - Graph was finalized.
# 2019-07-02 18:47:24,156 - tensorflow - INFO - Restoring parameters from s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-500
# 2019-07-02 18:47:24,335 - tensorflow - INFO - Running local_init_op.
# 2019-07-02 18:47:24,341 - tensorflow - INFO - Done running local_init_op.
# 2019-07-02 18:47:24,404 - tensorflow - INFO - Evaluation [1/10]
# 2019-07-02 18:47:24,413 - tensorflow - INFO - Evaluation [2/10]
# 2019-07-02 18:47:24,425 - tensorflow - INFO - Evaluation [3/10]
# 2019-07-02 18:47:24,439 - tensorflow - INFO - Evaluation [4/10]
# 2019-07-02 18:47:24,451 - tensorflow - INFO - Evaluation [5/10]
# 2019-07-02 18:47:24,464 - tensorflow - INFO - Evaluation [6/10]
# 2019-07-02 18:47:24,478 - tensorflow - INFO - Evaluation [7/10]
# 2019-07-02 18:47:24,491 - tensorflow - INFO - Evaluation [8/10]
# 2019-07-02 18:47:24,504 - tensorflow - INFO - Evaluation [9/10]
# 2019-07-02 18:47:24,518 - tensorflow - INFO - Evaluation [10/10]
# 2019-07-02 18:47:24,534 - tensorflow - INFO - Finished evaluation at 2019-07-02-18:47:24
# 2019-07-02 18:47:24,534 - tensorflow - INFO - Saving dict for global step 500: accuracy = 0.7609375, global_step = 500, loss = 0.76433235
# 2019-07-02 18:47:24.546458: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:47:24.546496: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:47:24.584982: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:47:24.585017: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:47:24.601200: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:47:24.601235: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:47:25,072 - tensorflow - INFO - Saving 'checkpoint_path' summary for global step 500: s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-500
# 2019-07-02 18:47:25,188 - tensorflow - INFO - global_step/sec: 14.8693
# 2019-07-02 18:47:25,189 - tensorflow - INFO - loss = 0.90263647, step = 501 (6.725 sec)
# 2019-07-02 18:47:28,030 - tensorflow - INFO - global_step/sec: 35.1863
# 2019-07-02 18:47:28,031 - tensorflow - INFO - loss = 0.52383846, step = 601 (2.842 sec)
# 2019-07-02 18:47:31,692 - tensorflow - INFO - global_step/sec: 27.3122
# 2019-07-02 18:47:31,693 - tensorflow - INFO - loss = 0.44048715, step = 701 (3.662 sec)
# 2019-07-02 18:47:35,264 - tensorflow - INFO - global_step/sec: 27.9899
# 2019-07-02 18:47:35,266 - tensorflow - INFO - loss = 0.7298758, step = 801 (3.573 sec)
# 2019-07-02 18:47:38,687 - tensorflow - INFO - global_step/sec: 29.2218
# 2019-07-02 18:47:38,688 - tensorflow - INFO - loss = 0.9928016, step = 901 (3.422 sec)
# 2019-07-02 18:47:42,760 - tensorflow - INFO - Saving checkpoints for 1000 into s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt.
# 2019-07-02 18:47:43.947977: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:47:43.948022: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:47:44,386 - tensorflow - INFO - Calling model_fn.
# 2019-07-02 18:47:44,537 - tensorflow - INFO - Done calling model_fn.
# 2019-07-02 18:47:44,559 - tensorflow - INFO - Starting evaluation at 2019-07-02-18:47:44
# 2019-07-02 18:47:44,740 - tensorflow - INFO - Graph was finalized.
# 2019-07-02 18:47:44,802 - tensorflow - INFO - Restoring parameters from s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-1000
# 2019-07-02 18:47:44,978 - tensorflow - INFO - Running local_init_op.
# 2019-07-02 18:47:44,984 - tensorflow - INFO - Done running local_init_op.
# 2019-07-02 18:47:45,035 - tensorflow - INFO - Evaluation [1/10]
# 2019-07-02 18:47:45,047 - tensorflow - INFO - Evaluation [2/10]
# 2019-07-02 18:47:45,060 - tensorflow - INFO - Evaluation [3/10]
# 2019-07-02 18:47:45,073 - tensorflow - INFO - Evaluation [4/10]
# 2019-07-02 18:47:45,086 - tensorflow - INFO - Evaluation [5/10]
# 2019-07-02 18:47:45,098 - tensorflow - INFO - Evaluation [6/10]
# 2019-07-02 18:47:45,118 - tensorflow - INFO - Evaluation [7/10]
# 2019-07-02 18:47:45,134 - tensorflow - INFO - Evaluation [8/10]
# 2019-07-02 18:47:45,151 - tensorflow - INFO - Evaluation [9/10]
# 2019-07-02 18:47:45,169 - tensorflow - INFO - Evaluation [10/10]
# 2019-07-02 18:47:45,191 - tensorflow - INFO - Finished evaluation at 2019-07-02-18:47:45
# 2019-07-02 18:47:45,191 - tensorflow - INFO - Saving dict for global step 1000: accuracy = 0.928125, global_step = 1000, loss = 0.32401612
# 2019-07-02 18:47:45,247 - tensorflow - INFO - Saving 'checkpoint_path' summary for global step 1000: s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-1000
# 2019-07-02 18:47:45,350 - tensorflow - INFO - global_step/sec: 15.0061
# 2019-07-02 18:47:45,352 - tensorflow - INFO - loss = 0.37389216, step = 1001 (6.664 sec)
# 2019-07-02 18:47:48,229 - tensorflow - INFO - global_step/sec: 34.7396
# 2019-07-02 18:47:48,230 - tensorflow - INFO - loss = 0.5550946, step = 1101 (2.879 sec)
# 2019-07-02 18:47:51,911 - tensorflow - INFO - global_step/sec: 27.1593
# 2019-07-02 18:47:51,912 - tensorflow - INFO - loss = 0.277103, step = 1201 (3.682 sec)
# 2019-07-02 18:47:55,151 - tensorflow - INFO - global_step/sec: 30.8668
# 2019-07-02 18:47:55,153 - tensorflow - INFO - loss = 0.4287386, step = 1301 (3.241 sec)
# 2019-07-02 18:47:58,579 - tensorflow - INFO - global_step/sec: 29.1665
# 2019-07-02 18:47:58,581 - tensorflow - INFO - loss = 0.40374422, step = 1401 (3.428 sec)
# 2019-07-02 18:48:02,165 - tensorflow - INFO - Saving checkpoints for 1500 into s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt.
# 2019-07-02 18:48:03.484582: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:48:03.484625: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:48:04,122 - tensorflow - INFO - Calling model_fn.
# 2019-07-02 18:48:04,278 - tensorflow - INFO - Done calling model_fn.
# 2019-07-02 18:48:04,301 - tensorflow - INFO - Starting evaluation at 2019-07-02-18:48:04
# 2019-07-02 18:48:04,401 - tensorflow - INFO - Graph was finalized.
# 2019-07-02 18:48:04,471 - tensorflow - INFO - Restoring parameters from s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-1500
# 2019-07-02 18:48:04,653 - tensorflow - INFO - Running local_init_op.
# 2019-07-02 18:48:04,659 - tensorflow - INFO - Done running local_init_op.
# 2019-07-02 18:48:04,710 - tensorflow - INFO - Evaluation [1/10]
# 2019-07-02 18:48:04,723 - tensorflow - INFO - Evaluation [2/10]
# 2019-07-02 18:48:04,736 - tensorflow - INFO - Evaluation [3/10]
# 2019-07-02 18:48:04,748 - tensorflow - INFO - Evaluation [4/10]
# 2019-07-02 18:48:04,761 - tensorflow - INFO - Evaluation [5/10]
# 2019-07-02 18:48:04,774 - tensorflow - INFO - Evaluation [6/10]
# 2019-07-02 18:48:04,787 - tensorflow - INFO - Evaluation [7/10]
# 2019-07-02 18:48:04,799 - tensorflow - INFO - Evaluation [8/10]
# 2019-07-02 18:48:04,813 - tensorflow - INFO - Evaluation [9/10]
# 2019-07-02 18:48:04,825 - tensorflow - INFO - Evaluation [10/10]
# 2019-07-02 18:48:04,840 - tensorflow - INFO - Finished evaluation at 2019-07-02-18:48:04
# 2019-07-02 18:48:04,840 - tensorflow - INFO - Saving dict for global step 1500: accuracy = 0.8640625, global_step = 1500, loss = 0.5218694
# 2019-07-02 18:48:04,895 - tensorflow - INFO - Saving 'checkpoint_path' summary for global step 1500: s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-1500
# 2019-07-02 18:48:04,987 - tensorflow - INFO - global_step/sec: 15.606
# 2019-07-02 18:48:04,988 - tensorflow - INFO - loss = 0.32266653, step = 1501 (6.407 sec)
# 2019-07-02 18:48:08,153 - tensorflow - INFO - global_step/sec: 31.5835
# 2019-07-02 18:48:08,155 - tensorflow - INFO - loss = 0.282652, step = 1601 (3.167 sec)
# 2019-07-02 18:48:12,283 - tensorflow - INFO - global_step/sec: 24.2175
# 2019-07-02 18:48:12,284 - tensorflow - INFO - loss = 0.5056141, step = 1701 (4.129 sec)
# 2019-07-02 18:48:16,034 - tensorflow - INFO - global_step/sec: 26.6568
# 2019-07-02 18:48:16,035 - tensorflow - INFO - loss = 0.4267323, step = 1801 (3.752 sec)
# 2019-07-02 18:48:20,649 - tensorflow - INFO - global_step/sec: 21.6684
# 2019-07-02 18:48:20,650 - tensorflow - INFO - loss = 0.15916735, step = 1901 (4.615 sec)
# 2019-07-02 18:48:24,555 - tensorflow - INFO - Saving checkpoints for 2000 into s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt.
# 2019-07-02 18:48:25.560978: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:48:25.561024: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:48:26,162 - tensorflow - INFO - Calling model_fn.
# 2019-07-02 18:48:26,310 - tensorflow - INFO - Done calling model_fn.
# 2019-07-02 18:48:26,334 - tensorflow - INFO - Starting evaluation at 2019-07-02-18:48:26
# 2019-07-02 18:48:26,433 - tensorflow - INFO - Graph was finalized.
# 2019-07-02 18:48:26,503 - tensorflow - INFO - Restoring parameters from s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-2000
# 2019-07-02 18:48:26,694 - tensorflow - INFO - Running local_init_op.
# 2019-07-02 18:48:26,699 - tensorflow - INFO - Done running local_init_op.
# 2019-07-02 18:48:26,749 - tensorflow - INFO - Evaluation [1/10]
# 2019-07-02 18:48:26,763 - tensorflow - INFO - Evaluation [2/10]
# 2019-07-02 18:48:26,782 - tensorflow - INFO - Evaluation [3/10]
# 2019-07-02 18:48:26,805 - tensorflow - INFO - Evaluation [4/10]
# 2019-07-02 18:48:27,106 - tensorflow - INFO - Evaluation [5/10]
# 2019-07-02 18:48:27,121 - tensorflow - INFO - Evaluation [6/10]
# 2019-07-02 18:48:27,134 - tensorflow - INFO - Evaluation [7/10]
# 2019-07-02 18:48:27,147 - tensorflow - INFO - Evaluation [8/10]
# 2019-07-02 18:48:27,160 - tensorflow - INFO - Evaluation [9/10]
# 2019-07-02 18:48:27,172 - tensorflow - INFO - Evaluation [10/10]
# 2019-07-02 18:48:27,189 - tensorflow - INFO - Finished evaluation at 2019-07-02-18:48:27
# 2019-07-02 18:48:27,190 - tensorflow - INFO - Saving dict for global step 2000: accuracy = 0.921875, global_step = 2000, loss = 0.28365773
# 2019-07-02 18:48:27,299 - tensorflow - INFO - Saving 'checkpoint_path' summary for global step 2000: s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-2000
# 2019-07-02 18:48:27,414 - tensorflow - INFO - global_step/sec: 14.7819
# 2019-07-02 18:48:27,415 - tensorflow - INFO - loss = 0.35900632, step = 2001 (6.765 sec)
# 2019-07-02 18:48:29,979 - tensorflow - INFO - global_step/sec: 38.9917
# 2019-07-02 18:48:29,980 - tensorflow - INFO - loss = 0.326855, step = 2101 (2.565 sec)
# 2019-07-02 18:48:33,692 - tensorflow - INFO - global_step/sec: 26.9332
# 2019-07-02 18:48:33,698 - tensorflow - INFO - loss = 0.45200408, step = 2201 (3.718 sec)
# 2019-07-02 18:48:36,902 - tensorflow - INFO - global_step/sec: 31.1534
# 2019-07-02 18:48:36,902 - tensorflow - INFO - loss = 0.36539024, step = 2301 (3.204 sec)
# 2019-07-02 18:48:40,210 - tensorflow - INFO - global_step/sec: 30.2274
# 2019-07-02 18:48:40,211 - tensorflow - INFO - loss = 0.9276402, step = 2401 (3.309 sec)
# 2019-07-02 18:48:44,324 - tensorflow - INFO - Saving checkpoints for 2500 into s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt.
# 2019-07-02 18:48:45.664410: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:48:45.664449: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:48:45,971 - tensorflow - INFO - Calling model_fn.
# 2019-07-02 18:48:46,122 - tensorflow - INFO - Done calling model_fn.
# 2019-07-02 18:48:46,146 - tensorflow - INFO - Starting evaluation at 2019-07-02-18:48:46
# 2019-07-02 18:48:46,247 - tensorflow - INFO - Graph was finalized.
# 2019-07-02 18:48:46,306 - tensorflow - INFO - Restoring parameters from s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-2500
# 2019-07-02 18:48:46,470 - tensorflow - INFO - Running local_init_op.
# 2019-07-02 18:48:46,476 - tensorflow - INFO - Done running local_init_op.
# 2019-07-02 18:48:46,527 - tensorflow - INFO - Evaluation [1/10]
# 2019-07-02 18:48:46,540 - tensorflow - INFO - Evaluation [2/10]
# 2019-07-02 18:48:46,553 - tensorflow - INFO - Evaluation [3/10]
# 2019-07-02 18:48:46,566 - tensorflow - INFO - Evaluation [4/10]
# 2019-07-02 18:48:46,579 - tensorflow - INFO - Evaluation [5/10]
# 2019-07-02 18:48:46,592 - tensorflow - INFO - Evaluation [6/10]
# 2019-07-02 18:48:46,604 - tensorflow - INFO - Evaluation [7/10]
# 2019-07-02 18:48:46,616 - tensorflow - INFO - Evaluation [8/10]
# 2019-07-02 18:48:46,630 - tensorflow - INFO - Evaluation [9/10]
# 2019-07-02 18:48:46,648 - tensorflow - INFO - Evaluation [10/10]
# 2019-07-02 18:48:46,664 - tensorflow - INFO - Finished evaluation at 2019-07-02-18:48:46
# 2019-07-02 18:48:46,665 - tensorflow - INFO - Saving dict for global step 2500: accuracy = 0.9765625, global_step = 2500, loss = 0.11363838
# 2019-07-02 18:48:46,835 - tensorflow - INFO - Saving 'checkpoint_path' summary for global step 2500: s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-2500
# 2019-07-02 18:48:46,968 - tensorflow - INFO - global_step/sec: 14.7965
# 2019-07-02 18:48:46,969 - tensorflow - INFO - loss = 0.43392608, step = 2501 (6.758 sec)
# 2019-07-02 18:48:50,241 - tensorflow - INFO - global_step/sec: 30.555
# 2019-07-02 18:48:50,242 - tensorflow - INFO - loss = 0.29549208, step = 2601 (3.273 sec)
# 2019-07-02 18:48:53,426 - tensorflow - INFO - global_step/sec: 31.3928
# 2019-07-02 18:48:53,427 - tensorflow - INFO - loss = 0.33523166, step = 2701 (3.186 sec)
# 2019-07-02 18:48:56,892 - tensorflow - INFO - global_step/sec: 28.8553
# 2019-07-02 18:48:56,894 - tensorflow - INFO - loss = 0.10501526, step = 2801 (3.466 sec)
# 2019-07-02 18:49:00,388 - tensorflow - INFO - global_step/sec: 28.6055
# 2019-07-02 18:49:00,389 - tensorflow - INFO - loss = 0.24266256, step = 2901 (3.495 sec)
# 2019-07-02 18:49:03,796 - tensorflow - INFO - Saving checkpoints for 3000 into s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt.
# 2019-07-02 18:49:05.374043: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:49:05.374084: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:49:05,956 - tensorflow - INFO - Calling model_fn.
# 2019-07-02 18:49:06,111 - tensorflow - INFO - Done calling model_fn.
# 2019-07-02 18:49:06,134 - tensorflow - INFO - Starting evaluation at 2019-07-02-18:49:06
# 2019-07-02 18:49:06,329 - tensorflow - INFO - Graph was finalized.
# 2019-07-02 18:49:06,391 - tensorflow - INFO - Restoring parameters from s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-3000
# 2019-07-02 18:49:06,571 - tensorflow - INFO - Running local_init_op.
# 2019-07-02 18:49:06,577 - tensorflow - INFO - Done running local_init_op.
# 2019-07-02 18:49:06,629 - tensorflow - INFO - Evaluation [1/10]
# 2019-07-02 18:49:06,642 - tensorflow - INFO - Evaluation [2/10]
# 2019-07-02 18:49:06,655 - tensorflow - INFO - Evaluation [3/10]
# 2019-07-02 18:49:06,669 - tensorflow - INFO - Evaluation [4/10]
# 2019-07-02 18:49:06,682 - tensorflow - INFO - Evaluation [5/10]
# 2019-07-02 18:49:06,697 - tensorflow - INFO - Evaluation [6/10]
# 2019-07-02 18:49:06,711 - tensorflow - INFO - Evaluation [7/10]
# 2019-07-02 18:49:06,725 - tensorflow - INFO - Evaluation [8/10]
# 2019-07-02 18:49:06,738 - tensorflow - INFO - Evaluation [9/10]
# 2019-07-02 18:49:06,751 - tensorflow - INFO - Evaluation [10/10]
# 2019-07-02 18:49:06,767 - tensorflow - INFO - Finished evaluation at 2019-07-02-18:49:06
# 2019-07-02 18:49:06,767 - tensorflow - INFO - Saving dict for global step 3000: accuracy = 0.965625, global_step = 3000, loss = 0.12927838
# 2019-07-02 18:49:06,842 - tensorflow - INFO - Saving 'checkpoint_path' summary for global step 3000: s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-3000
# 2019-07-02 18:49:06,898 - tensorflow - INFO - global_step/sec: 15.3603
# 2019-07-02 18:49:06,899 - tensorflow - INFO - loss = 0.35513848, step = 3001 (6.510 sec)
# 2019-07-02 18:49:09,829 - tensorflow - INFO - global_step/sec: 34.1228
# 2019-07-02 18:49:09,830 - tensorflow - INFO - loss = 0.40684557, step = 3101 (2.931 sec)
# 2019-07-02 18:49:13,476 - tensorflow - INFO - global_step/sec: 27.4136
# 2019-07-02 18:49:13,477 - tensorflow - INFO - loss = 0.36087728, step = 3201 (3.647 sec)
# 2019-07-02 18:49:16,728 - tensorflow - INFO - global_step/sec: 30.7597
# 2019-07-02 18:49:16,729 - tensorflow - INFO - loss = 0.39890814, step = 3301 (3.251 sec)
# 2019-07-02 18:49:21,020 - tensorflow - INFO - global_step/sec: 23.2941
# 2019-07-02 18:49:21,021 - tensorflow - INFO - loss = 0.24331903, step = 3401 (4.293 sec)
# 2019-07-02 18:49:25,731 - tensorflow - INFO - Saving checkpoints for 3500 into s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt.
# 2019-07-02 18:49:26.975550: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:49:26.975589: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:49:27,360 - tensorflow - INFO - Calling model_fn.
# 2019-07-02 18:49:27,508 - tensorflow - INFO - Done calling model_fn.
# 2019-07-02 18:49:27,530 - tensorflow - INFO - Starting evaluation at 2019-07-02-18:49:27
# 2019-07-02 18:49:27,629 - tensorflow - INFO - Graph was finalized.
# 2019-07-02 18:49:27,686 - tensorflow - INFO - Restoring parameters from s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-3500
# 2019-07-02 18:49:27,843 - tensorflow - INFO - Running local_init_op.
# 2019-07-02 18:49:27,848 - tensorflow - INFO - Done running local_init_op.
# 2019-07-02 18:49:27,899 - tensorflow - INFO - Evaluation [1/10]
# 2019-07-02 18:49:27,912 - tensorflow - INFO - Evaluation [2/10]
# 2019-07-02 18:49:27,925 - tensorflow - INFO - Evaluation [3/10]
# 2019-07-02 18:49:27,938 - tensorflow - INFO - Evaluation [4/10]
# 2019-07-02 18:49:27,957 - tensorflow - INFO - Evaluation [5/10]
# 2019-07-02 18:49:27,971 - tensorflow - INFO - Evaluation [6/10]
# 2019-07-02 18:49:27,986 - tensorflow - INFO - Evaluation [7/10]
# 2019-07-02 18:49:27,999 - tensorflow - INFO - Evaluation [8/10]
# 2019-07-02 18:49:28,017 - tensorflow - INFO - Evaluation [9/10]
# 2019-07-02 18:49:28,036 - tensorflow - INFO - Evaluation [10/10]
# 2019-07-02 18:49:28,055 - tensorflow - INFO - Finished evaluation at 2019-07-02-18:49:28
# 2019-07-02 18:49:28,056 - tensorflow - INFO - Saving dict for global step 3500: accuracy = 0.9375, global_step = 3500, loss = 0.22441213
# 2019-07-02 18:49:28,270 - tensorflow - INFO - Saving 'checkpoint_path' summary for global step 3500: s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-3500
# 2019-07-02 18:49:28,460 - tensorflow - INFO - global_step/sec: 13.4411
# 2019-07-02 18:49:28,462 - tensorflow - INFO - loss = 0.13059755, step = 3501 (7.440 sec)
# 2019-07-02 18:49:31,690 - tensorflow - INFO - global_step/sec: 30.9594
# 2019-07-02 18:49:31,692 - tensorflow - INFO - loss = 0.025559073, step = 3601 (3.230 sec)
# 2019-07-02 18:49:35,864 - tensorflow - INFO - global_step/sec: 23.9609
# 2019-07-02 18:49:35,865 - tensorflow - INFO - loss = 0.21321158, step = 3701 (4.174 sec)
# 2019-07-02 18:49:39,601 - tensorflow - INFO - global_step/sec: 26.7599
# 2019-07-02 18:49:39,602 - tensorflow - INFO - loss = 0.31026232, step = 3801 (3.737 sec)
# 2019-07-02 18:49:42,407 - tensorflow - INFO - global_step/sec: 35.6401
# 2019-07-02 18:49:42,408 - tensorflow - INFO - loss = 0.085260645, step = 3901 (2.806 sec)
# 2019-07-02 18:49:45,947 - tensorflow - INFO - Saving checkpoints for 4000 into s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt.
# 2019-07-02 18:49:47.524771: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:49:47.524809: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:49:47,912 - tensorflow - INFO - Calling model_fn.
# 2019-07-02 18:49:48,062 - tensorflow - INFO - Done calling model_fn.
# 2019-07-02 18:49:48,085 - tensorflow - INFO - Starting evaluation at 2019-07-02-18:49:48
# 2019-07-02 18:49:48,188 - tensorflow - INFO - Graph was finalized.
# 2019-07-02 18:49:48,257 - tensorflow - INFO - Restoring parameters from s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-4000
# 2019-07-02 18:49:48,412 - tensorflow - INFO - Running local_init_op.
# 2019-07-02 18:49:48,418 - tensorflow - INFO - Done running local_init_op.
# 2019-07-02 18:49:48,469 - tensorflow - INFO - Evaluation [1/10]
# 2019-07-02 18:49:48,482 - tensorflow - INFO - Evaluation [2/10]
# 2019-07-02 18:49:48,494 - tensorflow - INFO - Evaluation [3/10]
# 2019-07-02 18:49:48,508 - tensorflow - INFO - Evaluation [4/10]
# 2019-07-02 18:49:48,519 - tensorflow - INFO - Evaluation [5/10]
# 2019-07-02 18:49:48,531 - tensorflow - INFO - Evaluation [6/10]
# 2019-07-02 18:49:48,545 - tensorflow - INFO - Evaluation [7/10]
# 2019-07-02 18:49:48,557 - tensorflow - INFO - Evaluation [8/10]
# 2019-07-02 18:49:48,570 - tensorflow - INFO - Evaluation [9/10]
# 2019-07-02 18:49:48,583 - tensorflow - INFO - Evaluation [10/10]
# 2019-07-02 18:49:48,598 - tensorflow - INFO - Finished evaluation at 2019-07-02-18:49:48
# 2019-07-02 18:49:48,599 - tensorflow - INFO - Saving dict for global step 4000: accuracy = 0.9625, global_step = 4000, loss = 0.1407496
# 2019-07-02 18:49:48,692 - tensorflow - INFO - Saving 'checkpoint_path' summary for global step 4000: s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-4000
# 2019-07-02 18:49:48,762 - tensorflow - INFO - global_step/sec: 15.7346
# 2019-07-02 18:49:48,763 - tensorflow - INFO - loss = 0.15088154, step = 4001 (6.355 sec)
# 2019-07-02 18:49:51,961 - tensorflow - INFO - global_step/sec: 31.2549
# 2019-07-02 18:49:51,963 - tensorflow - INFO - loss = 0.2189039, step = 4101 (3.200 sec)
# 2019-07-02 18:49:55,890 - tensorflow - INFO - global_step/sec: 25.4564
# 2019-07-02 18:49:55,891 - tensorflow - INFO - loss = 0.25083867, step = 4201 (3.928 sec)
# 2019-07-02 18:49:59,916 - tensorflow - INFO - global_step/sec: 24.8373
# 2019-07-02 18:49:59,917 - tensorflow - INFO - loss = 0.064477004, step = 4301 (4.026 sec)
# 2019-07-02 18:50:03,321 - tensorflow - INFO - global_step/sec: 29.3666
# 2019-07-02 18:50:03,322 - tensorflow - INFO - loss = 0.27689973, step = 4401 (3.405 sec)
# 2019-07-02 18:50:07,003 - tensorflow - INFO - Saving checkpoints for 4500 into s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt.
# 2019-07-02 18:50:08.299978: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:50:08.300028: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:50:08,663 - tensorflow - INFO - Calling model_fn.
# 2019-07-02 18:50:08,811 - tensorflow - INFO - Done calling model_fn.
# 2019-07-02 18:50:08,835 - tensorflow - INFO - Starting evaluation at 2019-07-02-18:50:08
# 2019-07-02 18:50:08,932 - tensorflow - INFO - Graph was finalized.
# 2019-07-02 18:50:09,020 - tensorflow - INFO - Restoring parameters from s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-4500
# 2019-07-02 18:50:09,195 - tensorflow - INFO - Running local_init_op.
# 2019-07-02 18:50:09,201 - tensorflow - INFO - Done running local_init_op.
# 2019-07-02 18:50:09,260 - tensorflow - INFO - Evaluation [1/10]
# 2019-07-02 18:50:09,276 - tensorflow - INFO - Evaluation [2/10]
# 2019-07-02 18:50:09,298 - tensorflow - INFO - Evaluation [3/10]
# 2019-07-02 18:50:09,314 - tensorflow - INFO - Evaluation [4/10]
# 2019-07-02 18:50:09,579 - tensorflow - INFO - Evaluation [5/10]
# 2019-07-02 18:50:09,593 - tensorflow - INFO - Evaluation [6/10]
# 2019-07-02 18:50:09,605 - tensorflow - INFO - Evaluation [7/10]
# 2019-07-02 18:50:09,617 - tensorflow - INFO - Evaluation [8/10]
# 2019-07-02 18:50:09,631 - tensorflow - INFO - Evaluation [9/10]
# 2019-07-02 18:50:09,644 - tensorflow - INFO - Evaluation [10/10]
# 2019-07-02 18:50:09,660 - tensorflow - INFO - Finished evaluation at 2019-07-02-18:50:09
# 2019-07-02 18:50:09,660 - tensorflow - INFO - Saving dict for global step 4500: accuracy = 0.9796875, global_step = 4500, loss = 0.057816155
# 2019-07-02 18:50:09,756 - tensorflow - INFO - Saving 'checkpoint_path' summary for global step 4500: s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-4500
# 2019-07-02 18:50:09,840 - tensorflow - INFO - global_step/sec: 15.3412
# 2019-07-02 18:50:09,841 - tensorflow - INFO - loss = 0.086208954, step = 4501 (6.518 sec)
# 2019-07-02 18:50:12,838 - tensorflow - INFO - global_step/sec: 33.3493
# 2019-07-02 18:50:12,840 - tensorflow - INFO - loss = 0.4365328, step = 4601 (2.999 sec)
# 2019-07-02 18:50:16,102 - tensorflow - INFO - global_step/sec: 30.636
# 2019-07-02 18:50:16,104 - tensorflow - INFO - loss = 0.34644568, step = 4701 (3.264 sec)
# 2019-07-02 18:50:20,079 - tensorflow - INFO - global_step/sec: 25.1467
# 2019-07-02 18:50:20,080 - tensorflow - INFO - loss = 0.11381133, step = 4801 (3.977 sec)
# 2019-07-02 18:50:24,050 - tensorflow - INFO - global_step/sec: 25.1819
# 2019-07-02 18:50:24,051 - tensorflow - INFO - loss = 0.2504616, step = 4901 (3.971 sec)
# 2019-07-02 18:50:27,564 - tensorflow - INFO - Saving checkpoints for 5000 into s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt.
# 2019-07-02 18:50:28.844989: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:50:28.845056: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:50:29,244 - tensorflow - INFO - Calling model_fn.
# 2019-07-02 18:50:29,394 - tensorflow - INFO - Done calling model_fn.
# 2019-07-02 18:50:29,417 - tensorflow - INFO - Starting evaluation at 2019-07-02-18:50:29
# 2019-07-02 18:50:29,605 - tensorflow - INFO - Graph was finalized.
# 2019-07-02 18:50:29,669 - tensorflow - INFO - Restoring parameters from s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-5000
# 2019-07-02 18:50:29,918 - tensorflow - INFO - Running local_init_op.
# 2019-07-02 18:50:29,923 - tensorflow - INFO - Done running local_init_op.
# 2019-07-02 18:50:29,975 - tensorflow - INFO - Evaluation [1/10]
# 2019-07-02 18:50:29,989 - tensorflow - INFO - Evaluation [2/10]
# 2019-07-02 18:50:30,002 - tensorflow - INFO - Evaluation [3/10]
# 2019-07-02 18:50:30,016 - tensorflow - INFO - Evaluation [4/10]
# 2019-07-02 18:50:30,034 - tensorflow - INFO - Evaluation [5/10]
# 2019-07-02 18:50:30,058 - tensorflow - INFO - Evaluation [6/10]
# 2019-07-02 18:50:30,074 - tensorflow - INFO - Evaluation [7/10]
# 2019-07-02 18:50:30,094 - tensorflow - INFO - Evaluation [8/10]
# 2019-07-02 18:50:30,110 - tensorflow - INFO - Evaluation [9/10]
# 2019-07-02 18:50:30,131 - tensorflow - INFO - Evaluation [10/10]
# 2019-07-02 18:50:30,150 - tensorflow - INFO - Finished evaluation at 2019-07-02-18:50:30
# 2019-07-02 18:50:30,150 - tensorflow - INFO - Saving dict for global step 5000: accuracy = 0.9828125, global_step = 5000, loss = 0.053162385
# 2019-07-02 18:50:30,234 - tensorflow - INFO - Saving 'checkpoint_path' summary for global step 5000: s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-5000
# 2019-07-02 18:50:30,438 - tensorflow - INFO - global_step/sec: 15.6534
# 2019-07-02 18:50:30,440 - tensorflow - INFO - loss = 0.11119475, step = 5001 (6.389 sec)
# 2019-07-02 18:50:33,853 - tensorflow - INFO - global_step/sec: 29.2832
# 2019-07-02 18:50:33,855 - tensorflow - INFO - loss = 0.17594674, step = 5101 (3.415 sec)
# 2019-07-02 18:50:37,354 - tensorflow - INFO - global_step/sec: 28.566
# 2019-07-02 18:50:37,355 - tensorflow - INFO - loss = 0.03821931, step = 5201 (3.500 sec)
# 2019-07-02 18:50:40,765 - tensorflow - INFO - global_step/sec: 29.3148
# 2019-07-02 18:50:40,767 - tensorflow - INFO - loss = 0.10550964, step = 5301 (3.412 sec)
# 2019-07-02 18:50:43,876 - tensorflow - INFO - global_step/sec: 32.1487
# 2019-07-02 18:50:43,877 - tensorflow - INFO - loss = 0.29030272, step = 5401 (3.110 sec)
# 2019-07-02 18:50:47,098 - tensorflow - INFO - Saving checkpoints for 5500 into s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt.
# 2019-07-02 18:50:48.286933: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:50:48.286976: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:50:48,691 - tensorflow - INFO - Calling model_fn.
# 2019-07-02 18:50:48,839 - tensorflow - INFO - Done calling model_fn.
# 2019-07-02 18:50:48,861 - tensorflow - INFO - Starting evaluation at 2019-07-02-18:50:48
# 2019-07-02 18:50:48,960 - tensorflow - INFO - Graph was finalized.
# 2019-07-02 18:50:49,025 - tensorflow - INFO - Restoring parameters from s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-5500
# 2019-07-02 18:50:49,189 - tensorflow - INFO - Running local_init_op.
# 2019-07-02 18:50:49,194 - tensorflow - INFO - Done running local_init_op.
# 2019-07-02 18:50:49,244 - tensorflow - INFO - Evaluation [1/10]
# 2019-07-02 18:50:49,257 - tensorflow - INFO - Evaluation [2/10]
# 2019-07-02 18:50:49,270 - tensorflow - INFO - Evaluation [3/10]
# 2019-07-02 18:50:49,282 - tensorflow - INFO - Evaluation [4/10]
# 2019-07-02 18:50:49,295 - tensorflow - INFO - Evaluation [5/10]
# 2019-07-02 18:50:49,308 - tensorflow - INFO - Evaluation [6/10]
# 2019-07-02 18:50:49,319 - tensorflow - INFO - Evaluation [7/10]
# 2019-07-02 18:50:49,332 - tensorflow - INFO - Evaluation [8/10]
# 2019-07-02 18:50:49,344 - tensorflow - INFO - Evaluation [9/10]
# 2019-07-02 18:50:49,357 - tensorflow - INFO - Evaluation [10/10]
# 2019-07-02 18:50:49,372 - tensorflow - INFO - Finished evaluation at 2019-07-02-18:50:49
# 2019-07-02 18:50:49,372 - tensorflow - INFO - Saving dict for global step 5500: accuracy = 0.98125, global_step = 5500, loss = 0.051914223
# 2019-07-02 18:50:49,469 - tensorflow - INFO - Saving 'checkpoint_path' summary for global step 5500: s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-5500
# 2019-07-02 18:50:49,610 - tensorflow - INFO - global_step/sec: 17.4409
# 2019-07-02 18:50:49,615 - tensorflow - INFO - loss = 0.3848521, step = 5501 (5.738 sec)
# 2019-07-02 18:50:52,608 - tensorflow - INFO - global_step/sec: 33.3459
# 2019-07-02 18:50:52,610 - tensorflow - INFO - loss = 0.048525922, step = 5601 (2.995 sec)
# 2019-07-02 18:50:56,080 - tensorflow - INFO - global_step/sec: 28.806
# 2019-07-02 18:50:56,081 - tensorflow - INFO - loss = 0.13264537, step = 5701 (3.472 sec)
# 2019-07-02 18:50:59,788 - tensorflow - INFO - global_step/sec: 26.9699
# 2019-07-02 18:50:59,789 - tensorflow - INFO - loss = 0.20679973, step = 5801 (3.707 sec)
# 2019-07-02 18:51:02,992 - tensorflow - INFO - global_step/sec: 31.2099
# 2019-07-02 18:51:02,993 - tensorflow - INFO - loss = 0.11506958, step = 5901 (3.204 sec)
# ...
# 2019-07-02 18:52:03,440 - tensorflow - INFO - global_step/sec: 26.9194
# 2019-07-02 18:52:03,441 - tensorflow - INFO - loss = 0.17197493, step = 7301 (3.714 sec)
# 2019-07-02 18:52:07,047 - tensorflow - INFO - global_step/sec: 27.7242
# 2019-07-02 18:52:07,048 - tensorflow - INFO - loss = 0.082084, step = 7401 (3.607 sec)
# 2019-07-02 18:52:10,300 - tensorflow - INFO - Saving checkpoints for 7500 into s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt.
# 2019-07-02 18:52:11.769632: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:52:11.769673: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:52:12,178 - tensorflow - INFO - Calling model_fn.
# 2019-07-02 18:52:12,325 - tensorflow - INFO - Done calling model_fn.
# 2019-07-02 18:52:12,348 - tensorflow - INFO - Starting evaluation at 2019-07-02-18:52:12
# 2019-07-02 18:52:12,447 - tensorflow - INFO - Graph was finalized.
# 2019-07-02 18:52:12,507 - tensorflow - INFO - Restoring parameters from s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-7500
# 2019-07-02 18:52:12,754 - tensorflow - INFO - Running local_init_op.
# 2019-07-02 18:52:12,759 - tensorflow - INFO - Done running local_init_op.
# 2019-07-02 18:52:12,810 - tensorflow - INFO - Evaluation [1/10]
# 2019-07-02 18:52:12,823 - tensorflow - INFO - Evaluation [2/10]
# 2019-07-02 18:52:12,843 - tensorflow - INFO - Evaluation [3/10]
# 2019-07-02 18:52:12,859 - tensorflow - INFO - Evaluation [4/10]
# 2019-07-02 18:52:12,880 - tensorflow - INFO - Evaluation [5/10]
# 2019-07-02 18:52:12,902 - tensorflow - INFO - Evaluation [6/10]
# 2019-07-02 18:52:12,914 - tensorflow - INFO - Evaluation [7/10]
# 2019-07-02 18:52:13,169 - tensorflow - INFO - Evaluation [8/10]
# 2019-07-02 18:52:13,182 - tensorflow - INFO - Evaluation [9/10]
# 2019-07-02 18:52:13,194 - tensorflow - INFO - Evaluation [10/10]
# 2019-07-02 18:52:13,215 - tensorflow - INFO - Finished evaluation at 2019-07-02-18:52:13
# 2019-07-02 18:52:13,216 - tensorflow - INFO - Saving dict for global step 7500: accuracy = 0.96875, global_step = 7500, loss = 0.13576396
# 2019-07-02 18:52:13,266 - tensorflow - INFO - Saving 'checkpoint_path' summary for global step 7500: s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-7500
# 2019-07-02 18:52:13,376 - tensorflow - INFO - global_step/sec: 15.8005
# 2019-07-02 18:52:13,377 - tensorflow - INFO - loss = 0.21195753, step = 7501 (6.329 sec)
# 2019-07-02 18:52:16,292 - tensorflow - INFO - global_step/sec: 34.2928
# 2019-07-02 18:52:16,293 - tensorflow - INFO - loss = 0.15196513, step = 7601 (2.917 sec)
# 2019-07-02 18:52:19,662 - tensorflow - INFO - global_step/sec: 29.6688
# 2019-07-02 18:52:19,664 - tensorflow - INFO - loss = 0.10523659, step = 7701 (3.371 sec)
# 2019-07-02 18:52:23,258 - tensorflow - INFO - global_step/sec: 27.8144
# 2019-07-02 18:52:23,259 - tensorflow - INFO - loss = 0.01366056, step = 7801 (3.595 sec)
# 2019-07-02 18:52:26,854 - tensorflow - INFO - global_step/sec: 27.8082
# 2019-07-02 18:52:26,855 - tensorflow - INFO - loss = 0.1000916, step = 7901 (3.596 sec)
# 2019-07-02 18:52:30,296 - tensorflow - INFO - Saving checkpoints for 8000 into s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt.
# 2019-07-02 18:52:31.696193: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:52:31.696232: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:52:32,075 - tensorflow - INFO - Calling model_fn.
# 2019-07-02 18:52:32,317 - tensorflow - INFO - Done calling model_fn.
# 2019-07-02 18:52:32,340 - tensorflow - INFO - Starting evaluation at 2019-07-02-18:52:32
# 2019-07-02 18:52:32,443 - tensorflow - INFO - Graph was finalized.
# 2019-07-02 18:52:32,501 - tensorflow - INFO - Restoring parameters from s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-8000
# 2019-07-02 18:52:32,659 - tensorflow - INFO - Running local_init_op.
# 2019-07-02 18:52:32,665 - tensorflow - INFO - Done running local_init_op.
# 2019-07-02 18:52:32,717 - tensorflow - INFO - Evaluation [1/10]
# 2019-07-02 18:52:32,730 - tensorflow - INFO - Evaluation [2/10]
# 2019-07-02 18:52:32,743 - tensorflow - INFO - Evaluation [3/10]
# 2019-07-02 18:52:32,756 - tensorflow - INFO - Evaluation [4/10]
# 2019-07-02 18:52:32,769 - tensorflow - INFO - Evaluation [5/10]
# 2019-07-02 18:52:32,782 - tensorflow - INFO - Evaluation [6/10]
# 2019-07-02 18:52:32,795 - tensorflow - INFO - Evaluation [7/10]
# 2019-07-02 18:52:32,808 - tensorflow - INFO - Evaluation [8/10]
# 2019-07-02 18:52:32,826 - tensorflow - INFO - Evaluation [9/10]
# 2019-07-02 18:52:32,839 - tensorflow - INFO - Evaluation [10/10]
# 2019-07-02 18:52:32,853 - tensorflow - INFO - Finished evaluation at 2019-07-02-18:52:32
# 2019-07-02 18:52:32,854 - tensorflow - INFO - Saving dict for global step 8000: accuracy = 0.965625, global_step = 8000, loss = 0.12229706
# 2019-07-02 18:52:32,949 - tensorflow - INFO - Saving 'checkpoint_path' summary for global step 8000: s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-8000
# 2019-07-02 18:52:33,009 - tensorflow - INFO - global_step/sec: 16.2476
# 2019-07-02 18:52:33,010 - tensorflow - INFO - loss = 0.08642995, step = 8001 (6.155 sec)
# 2019-07-02 18:52:36,142 - tensorflow - INFO - global_step/sec: 31.9129
# 2019-07-02 18:52:36,144 - tensorflow - INFO - loss = 0.34062916, step = 8101 (3.134 sec)
# 2019-07-02 18:52:39,810 - tensorflow - INFO - global_step/sec: 27.2626
# 2019-07-02 18:52:39,811 - tensorflow - INFO - loss = 0.34421217, step = 8201 (3.668 sec)
# 2019-07-02 18:52:43,101 - tensorflow - INFO - global_step/sec: 30.3914
# 2019-07-02 18:52:43,102 - tensorflow - INFO - loss = 0.019097788, step = 8301 (3.291 sec)
# 2019-07-02 18:52:46,673 - tensorflow - INFO - global_step/sec: 27.9919
# 2019-07-02 18:52:46,674 - tensorflow - INFO - loss = 0.15632853, step = 8401 (3.572 sec)
# 2019-07-02 18:52:50,323 - tensorflow - INFO - Saving checkpoints for 8500 into s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt.
# 2019-07-02 18:52:51.755041: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:52:51.755078: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:52:52,223 - tensorflow - INFO - Calling model_fn.
# 2019-07-02 18:52:52,369 - tensorflow - INFO - Done calling model_fn.
# 2019-07-02 18:52:52,392 - tensorflow - INFO - Starting evaluation at 2019-07-02-18:52:52
# 2019-07-02 18:52:52,492 - tensorflow - INFO - Graph was finalized.
# 2019-07-02 18:52:52,551 - tensorflow - INFO - Restoring parameters from s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-8500
# 2019-07-02 18:52:52,720 - tensorflow - INFO - Running local_init_op.
# 2019-07-02 18:52:52,726 - tensorflow - INFO - Done running local_init_op.
# 2019-07-02 18:52:52,775 - tensorflow - INFO - Evaluation [1/10]
# 2019-07-02 18:52:52,789 - tensorflow - INFO - Evaluation [2/10]
# 2019-07-02 18:52:52,801 - tensorflow - INFO - Evaluation [3/10]
# 2019-07-02 18:52:52,813 - tensorflow - INFO - Evaluation [4/10]
# 2019-07-02 18:52:52,826 - tensorflow - INFO - Evaluation [5/10]
# 2019-07-02 18:52:52,839 - tensorflow - INFO - Evaluation [6/10]
# 2019-07-02 18:52:52,852 - tensorflow - INFO - Evaluation [7/10]
# 2019-07-02 18:52:52,864 - tensorflow - INFO - Evaluation [8/10]
# 2019-07-02 18:52:52,877 - tensorflow - INFO - Evaluation [9/10]
# 2019-07-02 18:52:52,890 - tensorflow - INFO - Evaluation [10/10]
# 2019-07-02 18:52:52,907 - tensorflow - INFO - Finished evaluation at 2019-07-02-18:52:52
# 2019-07-02 18:52:52,907 - tensorflow - INFO - Saving dict for global step 8500: accuracy = 0.9703125, global_step = 8500, loss = 0.06591032
# 2019-07-02 18:52:52,982 - tensorflow - INFO - Saving 'checkpoint_path' summary for global step 8500: s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-8500
# 2019-07-02 18:52:53,099 - tensorflow - INFO - global_step/sec: 15.5626
# 2019-07-02 18:52:53,100 - tensorflow - INFO - loss = 0.13656205, step = 8501 (6.426 sec)
# 2019-07-02 18:52:56,220 - tensorflow - INFO - global_step/sec: 32.0417
# 2019-07-02 18:52:56,221 - tensorflow - INFO - loss = 0.1068071, step = 8601 (3.121 sec)
# 2019-07-02 18:52:59,198 - tensorflow - INFO - global_step/sec: 33.5788
# 2019-07-02 18:52:59,199 - tensorflow - INFO - loss = 0.12705228, step = 8701 (2.978 sec)
# 2019-07-02 18:53:02,811 - tensorflow - INFO - global_step/sec: 27.6775
# 2019-07-02 18:53:02,812 - tensorflow - INFO - loss = 0.10623005, step = 8801 (3.613 sec)
# 2019-07-02 18:53:06,402 - tensorflow - INFO - global_step/sec: 27.8435
# 2019-07-02 18:53:06,403 - tensorflow - INFO - loss = 0.24040174, step = 8901 (3.592 sec)
# 2019-07-02 18:53:09,791 - tensorflow - INFO - Saving checkpoints for 9000 into s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt.
# 2019-07-02 18:53:11.330505: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:53:11.330544: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:53:12,036 - tensorflow - INFO - Calling model_fn.
# 2019-07-02 18:53:12,186 - tensorflow - INFO - Done calling model_fn.
# 2019-07-02 18:53:12,209 - tensorflow - INFO - Starting evaluation at 2019-07-02-18:53:12
# 2019-07-02 18:53:12,308 - tensorflow - INFO - Graph was finalized.
# 2019-07-02 18:53:12,599 - tensorflow - INFO - Restoring parameters from s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-9000
# 2019-07-02 18:53:13,074 - tensorflow - INFO - Running local_init_op.
# 2019-07-02 18:53:13,080 - tensorflow - INFO - Done running local_init_op.
# 2019-07-02 18:53:13,132 - tensorflow - INFO - Evaluation [1/10]
# 2019-07-02 18:53:13,146 - tensorflow - INFO - Evaluation [2/10]
# 2019-07-02 18:53:13,159 - tensorflow - INFO - Evaluation [3/10]
# 2019-07-02 18:53:13,172 - tensorflow - INFO - Evaluation [4/10]
# 2019-07-02 18:53:13,192 - tensorflow - INFO - Evaluation [5/10]
# 2019-07-02 18:53:13,204 - tensorflow - INFO - Evaluation [6/10]
# 2019-07-02 18:53:13,217 - tensorflow - INFO - Evaluation [7/10]
# 2019-07-02 18:53:13,234 - tensorflow - INFO - Evaluation [8/10]
# 2019-07-02 18:53:13,246 - tensorflow - INFO - Evaluation [9/10]
# 2019-07-02 18:53:13,462 - tensorflow - INFO - Evaluation [10/10]
# 2019-07-02 18:53:13,478 - tensorflow - INFO - Finished evaluation at 2019-07-02-18:53:13
# 2019-07-02 18:53:13,478 - tensorflow - INFO - Saving dict for global step 9000: accuracy = 0.9640625, global_step = 9000, loss = 0.13518196
# 2019-07-02 18:53:14,116 - tensorflow - INFO - Saving 'checkpoint_path' summary for global step 9000: s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-9000
# 2019-07-02 18:53:14,188 - tensorflow - INFO - global_step/sec: 12.8434
# 2019-07-02 18:53:14,189 - tensorflow - INFO - loss = 0.4716417, step = 9001 (7.786 sec)
# 2019-07-02 18:53:17,308 - tensorflow - INFO - global_step/sec: 32.054
# 2019-07-02 18:53:17,309 - tensorflow - INFO - loss = 0.20660187, step = 9101 (3.120 sec)
# 2019-07-02 18:53:20,673 - tensorflow - INFO - global_step/sec: 29.7173
# 2019-07-02 18:53:20,674 - tensorflow - INFO - loss = 0.3414672, step = 9201 (3.365 sec)
# 2019-07-02 18:53:24,447 - tensorflow - INFO - global_step/sec: 26.4982
# 2019-07-02 18:53:24,448 - tensorflow - INFO - loss = 0.1032249, step = 9301 (3.774 sec)
# 2019-07-02 18:53:27,130 - tensorflow - INFO - Saving checkpoints for 9375 into s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt.
# 2019-07-02 18:53:28.842279: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:53:28.842377: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:53:29,395 - tensorflow - INFO - Calling model_fn.
# 2019-07-02 18:53:29,543 - tensorflow - INFO - Done calling model_fn.
# 2019-07-02 18:53:29,567 - tensorflow - INFO - Starting evaluation at 2019-07-02-18:53:29
# 2019-07-02 18:53:29,668 - tensorflow - INFO - Graph was finalized.
# 2019-07-02 18:53:29,730 - tensorflow - INFO - Restoring parameters from s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-9375
# 2019-07-02 18:53:29,896 - tensorflow - INFO - Running local_init_op.
# 2019-07-02 18:53:29,902 - tensorflow - INFO - Done running local_init_op.
# 2019-07-02 18:53:29,952 - tensorflow - INFO - Evaluation [1/10]
# 2019-07-02 18:53:29,966 - tensorflow - INFO - Evaluation [2/10]
# 2019-07-02 18:53:29,978 - tensorflow - INFO - Evaluation [3/10]
# 2019-07-02 18:53:29,991 - tensorflow - INFO - Evaluation [4/10]
# 2019-07-02 18:53:30,004 - tensorflow - INFO - Evaluation [5/10]
# 2019-07-02 18:53:30,017 - tensorflow - INFO - Evaluation [6/10]
# 2019-07-02 18:53:30,030 - tensorflow - INFO - Evaluation [7/10]
# 2019-07-02 18:53:30,043 - tensorflow - INFO - Evaluation [8/10]
# 2019-07-02 18:53:30,057 - tensorflow - INFO - Evaluation [9/10]
# 2019-07-02 18:53:30,070 - tensorflow - INFO - Evaluation [10/10]
# 2019-07-02 18:53:30,087 - tensorflow - INFO - Finished evaluation at 2019-07-02-18:53:30
# 2019-07-02 18:53:30,087 - tensorflow - INFO - Saving dict for global step 9375: accuracy = 0.965625, global_step = 9375, loss = 0.14460222
# 2019-07-02 18:53:30,167 - tensorflow - INFO - Saving 'checkpoint_path' summary for global step 9375: s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-43-48-315/model/model.ckpt-9375
# 2019-07-02 18:53:30,215 - tensorflow - DEBUG - Calling exporter with the `is_the_final_export=True`.
# 2019-07-02 18:53:30,345 - tensorflow - INFO - Loss for final step: 0.12066976.
# 2019-07-02 18:53:30,746 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://github.com/aws/sagemaker-python-sdk/tree/master/src/sagemaker/tensorflow#adapting-your-local-tensorflow-script
# 2019-07-02 18:53:30,747 sagemaker-containers INFO     Reporting training SUCCESS
# 2019-07-02 18:53:37 Uploading - Uploading generated training model
# 2019-07-02 18:53:37 Completed - Training job completed
# Billable seconds: 470
# CPU times: user 1.24 s, sys: 132 ms, total: 1.37 s
# Wall time: 10min 17s

# %% [markdown]
# Accuracy should be around 0.95 and wall time = 10min 17s

# %% [markdown]
# # Training on 5 sagemaker instances

# %% [markdown]
# With just minimal code changes, we can the same number of steps in total but distributed over 5 instances

# %%
kwargs['train_instance_count'] = 5
mnist_estimator = TensorFlow(**kwargs)
# %time  mnist_estimator.fit(inputs=None)
# Out:
# 2019-07-02 18:54:06 Starting - Starting the training job...
# 2019-07-02 18:54:07 Starting - Launching requested ML instances......
# 2019-07-02 18:55:08 Starting - Preparing the instances for training......
# 2019-07-02 18:56:12 Downloading - Downloading input data
# 2019-07-02 18:56:12 Training - Downloading the training image....
# 2019-07-02 18:57:09,640 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2019-07-02 18:57:09,646 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-07-02 18:57:09,807 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2019-07-02 18:57:09,807 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# 2019-07-02 18:57:09,807 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2019-07-02 18:57:09,851 sagemaker_tensorflow_container.training INFO     Launching worker process
# 2019-07-02 18:57:09,957 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-07-02 18:57:09,972 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-07-02 18:57:09,982 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {},
#     "current_host": "algo-3",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3",
#         "algo-4",
#         "algo-5"
#     ],
#     "hyperparameters": {
#         "batch_size": 64,
#         "evaluation_steps": 10,
#         "dataset-url": "s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/",
#         "model_dir": "s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model",
#         "training_steps": 9375
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "petastorm-sagemaker-2019-07-02-18-54-05-832",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/code/petastorm-sagemaker-2019-07-02-18-54-05-832/source/sourcedir.tar.gz",
#     "module_name": "model",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-3",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3",
#             "algo-4",
#             "algo-5"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "model.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2","algo-3","algo-4","algo-5"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":64,"dataset-url":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/","evaluation_steps":10,"model_dir":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model","training_steps":9375}
# SM_USER_ENTRY_POINT=model.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-3","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-3
# SM_MODULE_NAME=model
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/code/petastorm-sagemaker-2019-07-02-18-54-05-832/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{},"current_host":"algo-3","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"hyperparameters":{"batch_size":64,"dataset-url":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/","evaluation_steps":10,"model_dir":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model","training_steps":9375},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":false,"job_name":"petastorm-sagemaker-2019-07-02-18-54-05-832","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/code/petastorm-sagemaker-2019-07-02-18-54-05-832/source/sourcedir.tar.gz","module_name":"model","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-3","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"network_interface_name":"eth0"},"user_entry_point":"model.py"}
# SM_USER_ARGS=["--batch_size","64","--dataset-url","s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/","--evaluation_steps","10","--model_dir","s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model","--training_steps","9375"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_BATCH_SIZE=64
# SM_HP_EVALUATION_STEPS=10
# SM_HP_DATASET-URL=s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/
# SM_HP_MODEL_DIR=s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model
# SM_HP_TRAINING_STEPS=9375
# TF_CONFIG={"cluster": {"master": ["algo-1:2222"], "ps": ["algo-1:2223", "algo-2:2223", "algo-3:2223", "algo-4:2223", "algo-5:2223"], "worker": ["algo-2:2222", "algo-3:2222", "algo-4:2222", "algo-5:2222"]}, "environment": "cloud", "task": {"index": 1, "type": "worker"}}
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python model.py --batch_size 64 --dataset-url s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/ --evaluation_steps 10 --model_dir s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model --training_steps 9375
#
#
# 2019-07-02 18:57:11,315 - tensorflow - INFO - TF_CONFIG environment variable: {'cluster': {'master': ['algo-1:2222'], 'ps': ['algo-1:2223', 'algo-2:2223', 'algo-3:2223', 'algo-4:2223', 'algo-5:2223'], 'worker': ['algo-2:2222', 'algo-3:2222', 'algo-4:2222', 'algo-5:2222']}, 'environment': 'cloud', 'task': {'index': 1, 'type': 'worker'}}
# Launch tensorboard by running the following in terminal:
# aws s3 sync {model_dir_parent_path} ~/Downloads/{model_dir_parent} && tensorboard --logdir=~/Downloads/{model_dir_parent}
# 2019-07-02 18:57:11,315 - tensorflow - INFO - Using config: {'_model_dir': 's3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model', '_tf_random_seed': None, '_save_summary_steps': 50, '_save_checkpoints_steps': 500, '_save_checkpoints_secs': None, '_session_config': device_filters: "/job:ps"
# device_filters: "/job:worker/task:1"
# allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f43cbc11be0>, '_task_type': 'worker', '_task_id': 1, '_global_id_in_cluster': 2, '_master': 'grpc://algo-3:2222', '_evaluation_master': '', '_num_ps_replicas': 5, '_num_worker_replicas': 5, '_is_chief': False}
# Inside training script on worker with (0-based) index 2 out of 4.
# 2019-07-02 18:57:11,658 - tensorflow - INFO - Not using Distribute Coordinator.
# 2019-07-02 18:57:11,663 - tensorflow - INFO - Start Tensorflow server.
# 2019-07-02 18:57:11,749 - tensorflow - INFO - Waiting 10 secs before starting training.
# 2019-07-02 18:57:10,680 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2019-07-02 18:57:10,686 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-07-02 18:57:10,836 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2019-07-02 18:57:10,837 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# 2019-07-02 18:57:10,837 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2019-07-02 18:57:10,879 sagemaker_tensorflow_container.training INFO     Launching worker process
# 2019-07-02 18:57:10,998 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-07-02 18:57:11,016 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-07-02 18:57:11,026 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3",
#         "algo-4",
#         "algo-5"
#     ],
#     "hyperparameters": {
#         "batch_size": 64,
#         "evaluation_steps": 10,
#         "dataset-url": "s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/",
#         "model_dir": "s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model",
#         "training_steps": 9375
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "petastorm-sagemaker-2019-07-02-18-54-05-832",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/code/petastorm-sagemaker-2019-07-02-18-54-05-832/source/sourcedir.tar.gz",
#     "module_name": "model",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3",
#             "algo-4",
#             "algo-5"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "model.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2","algo-3","algo-4","algo-5"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":64,"dataset-url":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/","evaluation_steps":10,"model_dir":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model","training_steps":9375}
# SM_USER_ENTRY_POINT=model.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=model
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/code/petastorm-sagemaker-2019-07-02-18-54-05-832/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"hyperparameters":{"batch_size":64,"dataset-url":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/","evaluation_steps":10,"model_dir":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model","training_steps":9375},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"petastorm-sagemaker-2019-07-02-18-54-05-832","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/code/petastorm-sagemaker-2019-07-02-18-54-05-832/source/sourcedir.tar.gz","module_name":"model","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"network_interface_name":"eth0"},"user_entry_point":"model.py"}
# SM_USER_ARGS=["--batch_size","64","--dataset-url","s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/","--evaluation_steps","10","--model_dir","s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model","--training_steps","9375"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_BATCH_SIZE=64
# SM_HP_EVALUATION_STEPS=10
# SM_HP_DATASET-URL=s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/
# SM_HP_MODEL_DIR=s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model
# SM_HP_TRAINING_STEPS=9375
# TF_CONFIG={"cluster": {"master": ["algo-1:2222"], "ps": ["algo-1:2223", "algo-2:2223", "algo-3:2223", "algo-4:2223", "algo-5:2223"], "worker": ["algo-2:2222", "algo-3:2222", "algo-4:2222", "algo-5:2222"]}, "environment": "cloud", "task": {"index": 0, "type": "master"}}
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python model.py --batch_size 64 --dataset-url s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/ --evaluation_steps 10 --model_dir s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model --training_steps 9375
#
#
# 2019-07-02 18:57:10,967 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2019-07-02 18:57:10,973 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-07-02 18:57:11,126 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2019-07-02 18:57:11,127 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# 2019-07-02 18:57:11,127 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2019-07-02 18:57:11,176 sagemaker_tensorflow_container.training INFO     Launching worker process
# 2019-07-02 18:57:11,280 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-07-02 18:57:11,295 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-07-02 18:57:11,306 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {},
#     "current_host": "algo-5",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3",
#         "algo-4",
#         "algo-5"
#     ],
#     "hyperparameters": {
#         "batch_size": 64,
#         "evaluation_steps": 10,
#         "dataset-url": "s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/",
#         "model_dir": "s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model",
#         "training_steps": 9375
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "petastorm-sagemaker-2019-07-02-18-54-05-832",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/code/petastorm-sagemaker-2019-07-02-18-54-05-832/source/sourcedir.tar.gz",
#     "module_name": "model",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-5",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3",
#             "algo-4",
#             "algo-5"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "model.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2","algo-3","algo-4","algo-5"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":64,"dataset-url":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/","evaluation_steps":10,"model_dir":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model","training_steps":9375}
# SM_USER_ENTRY_POINT=model.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-5","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-5
# SM_MODULE_NAME=model
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/code/petastorm-sagemaker-2019-07-02-18-54-05-832/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{},"current_host":"algo-5","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"hyperparameters":{"batch_size":64,"dataset-url":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/","evaluation_steps":10,"model_dir":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model","training_steps":9375},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":false,"job_name":"petastorm-sagemaker-2019-07-02-18-54-05-832","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/code/petastorm-sagemaker-2019-07-02-18-54-05-832/source/sourcedir.tar.gz","module_name":"model","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-5","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"network_interface_name":"eth0"},"user_entry_point":"model.py"}
# SM_USER_ARGS=["--batch_size","64","--dataset-url","s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/","--evaluation_steps","10","--model_dir","s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model","--training_steps","9375"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_BATCH_SIZE=64
# SM_HP_EVALUATION_STEPS=10
# SM_HP_DATASET-URL=s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/
# SM_HP_MODEL_DIR=s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model
# SM_HP_TRAINING_STEPS=9375
# TF_CONFIG={"cluster": {"master": ["algo-1:2222"], "ps": ["algo-1:2223", "algo-2:2223", "algo-3:2223", "algo-4:2223", "algo-5:2223"], "worker": ["algo-2:2222", "algo-3:2222", "algo-4:2222", "algo-5:2222"]}, "environment": "cloud", "task": {"index": 3, "type": "worker"}}
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python model.py --batch_size 64 --dataset-url s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/ --evaluation_steps 10 --model_dir s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model --training_steps 9375
#
#
# 2019-07-02 18:57:09,557 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2019-07-02 18:57:09,563 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-07-02 18:57:09,721 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2019-07-02 18:57:09,721 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# 2019-07-02 18:57:09,721 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2019-07-02 18:57:09,766 sagemaker_tensorflow_container.training INFO     Launching worker process
# 2019-07-02 18:57:09,914 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-07-02 18:57:09,929 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-07-02 18:57:09,940 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {},
#     "current_host": "algo-2",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3",
#         "algo-4",
#         "algo-5"
#     ],
#     "hyperparameters": {
#         "batch_size": 64,
#         "evaluation_steps": 10,
#         "dataset-url": "s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/",
#         "model_dir": "s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model",
#         "training_steps": 9375
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "petastorm-sagemaker-2019-07-02-18-54-05-832",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/code/petastorm-sagemaker-2019-07-02-18-54-05-832/source/sourcedir.tar.gz",
#     "module_name": "model",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-2",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3",
#             "algo-4",
#             "algo-5"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "model.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2","algo-3","algo-4","algo-5"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":64,"dataset-url":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/","evaluation_steps":10,"model_dir":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model","training_steps":9375}
# SM_USER_ENTRY_POINT=model.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-2","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-2
# SM_MODULE_NAME=model
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/code/petastorm-sagemaker-2019-07-02-18-54-05-832/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{},"current_host":"algo-2","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"hyperparameters":{"batch_size":64,"dataset-url":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/","evaluation_steps":10,"model_dir":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model","training_steps":9375},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":false,"job_name":"petastorm-sagemaker-2019-07-02-18-54-05-832","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/code/petastorm-sagemaker-2019-07-02-18-54-05-832/source/sourcedir.tar.gz","module_name":"model","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-2","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"network_interface_name":"eth0"},"user_entry_point":"model.py"}
# SM_USER_ARGS=["--batch_size","64","--dataset-url","s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/","--evaluation_steps","10","--model_dir","s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model","--training_steps","9375"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_BATCH_SIZE=64
# SM_HP_EVALUATION_STEPS=10
# SM_HP_DATASET-URL=s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/
# SM_HP_MODEL_DIR=s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model
# SM_HP_TRAINING_STEPS=9375
# TF_CONFIG={"cluster": {"master": ["algo-1:2222"], "ps": ["algo-1:2223", "algo-2:2223", "algo-3:2223", "algo-4:2223", "algo-5:2223"], "worker": ["algo-2:2222", "algo-3:2222", "algo-4:2222", "algo-5:2222"]}, "environment": "cloud", "task": {"index": 0, "type": "worker"}}
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python model.py --batch_size 64 --dataset-url s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/ --evaluation_steps 10 --model_dir s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model --training_steps 9375
#
#
# 2019-07-02 18:57:11,270 - tensorflow - INFO - TF_CONFIG environment variable: {'cluster': {'master': ['algo-1:2222'], 'ps': ['algo-1:2223', 'algo-2:2223', 'algo-3:2223', 'algo-4:2223', 'algo-5:2223'], 'worker': ['algo-2:2222', 'algo-3:2222', 'algo-4:2222', 'algo-5:2222']}, 'environment': 'cloud', 'task': {'index': 0, 'type': 'worker'}}
# Launch tensorboard by running the following in terminal:
# aws s3 sync {model_dir_parent_path} ~/Downloads/{model_dir_parent} && tensorboard --logdir=~/Downloads/{model_dir_parent}
# 2019-07-02 18:57:11,270 - tensorflow - INFO - Using config: {'_model_dir': 's3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model', '_tf_random_seed': None, '_save_summary_steps': 50, '_save_checkpoints_steps': 500, '_save_checkpoints_secs': None, '_session_config': device_filters: "/job:ps"
# device_filters: "/job:worker/task:0"
# allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fdfc4f12b70>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 1, '_master': 'grpc://algo-2:2222', '_evaluation_master': '', '_num_ps_replicas': 5, '_num_worker_replicas': 5, '_is_chief': False}
# Inside training script on worker with (0-based) index 1 out of 4.
# 2019-07-02 18:57:11,680 - tensorflow - INFO - Not using Distribute Coordinator.
# 2019-07-02 18:57:11,685 - tensorflow - INFO - Start Tensorflow server.
# 2019-07-02 18:57:11,748 - tensorflow - INFO - Waiting 5 secs before starting training.
# 2019-07-02 18:57:12,513 - tensorflow - INFO - TF_CONFIG environment variable: {'cluster': {'master': ['algo-1:2222'], 'ps': ['algo-1:2223', 'algo-2:2223', 'algo-3:2223', 'algo-4:2223', 'algo-5:2223'], 'worker': ['algo-2:2222', 'algo-3:2222', 'algo-4:2222', 'algo-5:2222']}, 'environment': 'cloud', 'task': {'index': 0, 'type': 'master'}}
# Launch tensorboard by running the following in terminal:
# aws s3 sync {model_dir_parent_path} ~/Downloads/{model_dir_parent} && tensorboard --logdir=~/Downloads/{model_dir_parent}
# 2019-07-02 18:57:12,514 - tensorflow - INFO - Using config: {'_model_dir': 's3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model', '_tf_random_seed': None, '_save_summary_steps': 50, '_save_checkpoints_steps': 500, '_save_checkpoints_secs': None, '_session_config': device_filters: "/job:ps"
# device_filters: "/job:master"
# allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7faf68f51be0>, '_task_type': 'master', '_task_id': 0, '_global_id_in_cluster': 0, '_master': 'grpc://algo-1:2222', '_evaluation_master': '', '_num_ps_replicas': 5, '_num_worker_replicas': 5, '_is_chief': True}
# Inside training script on worker with (0-based) index 0 out of 4.
# 2019-07-02 18:57:12,859 - tensorflow - INFO - Not using Distribute Coordinator.
# 2019-07-02 18:57:12,861 - tensorflow - INFO - Start Tensorflow server.
# 2019-07-02 18:57:13.030926: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:57:13.031030: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:57:12,719 - tensorflow - INFO - TF_CONFIG environment variable: {'cluster': {'master': ['algo-1:2222'], 'ps': ['algo-1:2223', 'algo-2:2223', 'algo-3:2223', 'algo-4:2223', 'algo-5:2223'], 'worker': ['algo-2:2222', 'algo-3:2222', 'algo-4:2222', 'algo-5:2222']}, 'environment': 'cloud', 'task': {'index': 3, 'type': 'worker'}}
# Launch tensorboard by running the following in terminal:
# aws s3 sync {model_dir_parent_path} ~/Downloads/{model_dir_parent} && tensorboard --logdir=~/Downloads/{model_dir_parent}
# 2019-07-02 18:57:12,720 - tensorflow - INFO - Using config: {'_model_dir': 's3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model', '_tf_random_seed': None, '_save_summary_steps': 50, '_save_checkpoints_steps': 500, '_save_checkpoints_secs': None, '_session_config': device_filters: "/job:ps"
# device_filters: "/job:worker/task:3"
# allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fe0999d1be0>, '_task_type': 'worker', '_task_id': 3, '_global_id_in_cluster': 4, '_master': 'grpc://algo-5:2222', '_evaluation_master': '', '_num_ps_replicas': 5, '_num_worker_replicas': 5, '_is_chief': False}
# Inside training script on worker with (0-based) index 4 out of 4.
# 2019-07-02 18:57:13,021 - tensorflow - INFO - Not using Distribute Coordinator.
# 2019-07-02 18:57:13,032 - tensorflow - INFO - Start Tensorflow server.
# 2019-07-02 18:57:13,111 - tensorflow - INFO - Waiting 20 secs before starting training.
# 2019-07-02 18:57:12,273 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2019-07-02 18:57:12,278 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-07-02 18:57:12,541 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2019-07-02 18:57:12,541 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# 2019-07-02 18:57:12,541 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2019-07-02 18:57:12,590 sagemaker_tensorflow_container.training INFO     Launching worker process
# 2019-07-02 18:57:12,710 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-07-02 18:57:12,726 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-07-02 18:57:12,736 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {},
#     "current_host": "algo-4",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3",
#         "algo-4",
#         "algo-5"
#     ],
#     "hyperparameters": {
#         "batch_size": 64,
#         "evaluation_steps": 10,
#         "dataset-url": "s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/",
#         "model_dir": "s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model",
#         "training_steps": 9375
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "petastorm-sagemaker-2019-07-02-18-54-05-832",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/code/petastorm-sagemaker-2019-07-02-18-54-05-832/source/sourcedir.tar.gz",
#     "module_name": "model",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-4",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3",
#             "algo-4",
#             "algo-5"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "model.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2","algo-3","algo-4","algo-5"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":64,"dataset-url":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/","evaluation_steps":10,"model_dir":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model","training_steps":9375}
# SM_USER_ENTRY_POINT=model.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-4","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-4
# SM_MODULE_NAME=model
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/code/petastorm-sagemaker-2019-07-02-18-54-05-832/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{},"current_host":"algo-4","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"hyperparameters":{"batch_size":64,"dataset-url":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/","evaluation_steps":10,"model_dir":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model","training_steps":9375},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":false,"job_name":"petastorm-sagemaker-2019-07-02-18-54-05-832","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/code/petastorm-sagemaker-2019-07-02-18-54-05-832/source/sourcedir.tar.gz","module_name":"model","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-4","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"network_interface_name":"eth0"},"user_entry_point":"model.py"}
# SM_USER_ARGS=["--batch_size","64","--dataset-url","s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/","--evaluation_steps","10","--model_dir","s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model","--training_steps","9375"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_BATCH_SIZE=64
# SM_HP_EVALUATION_STEPS=10
# SM_HP_DATASET-URL=s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/
# SM_HP_MODEL_DIR=s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model
# SM_HP_TRAINING_STEPS=9375
# TF_CONFIG={"cluster": {"master": ["algo-1:2222"], "ps": ["algo-1:2223", "algo-2:2223", "algo-3:2223", "algo-4:2223", "algo-5:2223"], "worker": ["algo-2:2222", "algo-3:2222", "algo-4:2222", "algo-5:2222"]}, "environment": "cloud", "task": {"index": 2, "type": "worker"}}
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python model.py --batch_size 64 --dataset-url s3://com.climate.production.analytics/dsw/scratch/sagemaker/sdegryze/mnist/ --evaluation_steps 10 --model_dir s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model --training_steps 9375
#
#
# 2019-07-02 18:57:14,268 - tensorflow - INFO - TF_CONFIG environment variable: {'cluster': {'master': ['algo-1:2222'], 'ps': ['algo-1:2223', 'algo-2:2223', 'algo-3:2223', 'algo-4:2223', 'algo-5:2223'], 'worker': ['algo-2:2222', 'algo-3:2222', 'algo-4:2222', 'algo-5:2222']}, 'environment': 'cloud', 'task': {'index': 2, 'type': 'worker'}}
# Launch tensorboard by running the following in terminal:
# aws s3 sync {model_dir_parent_path} ~/Downloads/{model_dir_parent} && tensorboard --logdir=~/Downloads/{model_dir_parent}
# 2019-07-02 18:57:14,269 - tensorflow - INFO - Using config: {'_model_dir': 's3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model', '_tf_random_seed': None, '_save_summary_steps': 50, '_save_checkpoints_steps': 500, '_save_checkpoints_secs': None, '_session_config': device_filters: "/job:ps"
# device_filters: "/job:worker/task:2"
# allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc243511be0>, '_task_type': 'worker', '_task_id': 2, '_global_id_in_cluster': 3, '_master': 'grpc://algo-4:2222', '_evaluation_master': '', '_num_ps_replicas': 5, '_num_worker_replicas': 5, '_is_chief': False}
# Inside training script on worker with (0-based) index 3 out of 4.
# 2019-07-02 18:57:14,580 - tensorflow - INFO - Not using Distribute Coordinator.
# 2019-07-02 18:57:14,582 - tensorflow - INFO - Start Tensorflow server.
# 2019-07-02 18:57:14,614 - tensorflow - INFO - Waiting 15 secs before starting training.
# 2019-07-02 18:57:16.828492: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:57:16.828531: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:57:21.863902: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:57:21.863943: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:57:21,919 - tensorflow - WARNING - From model.py:84: map_and_batch (from tensorflow.contrib.data.python.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.experimental.map_and_batch(...)`.
# 2019-07-02 18:57:22,246 - tensorflow - WARNING - From model.py:84: map_and_batch (from tensorflow.contrib.data.python.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.experimental.map_and_batch(...)`.
# 2019-07-02 18:57:22,269 - tensorflow - INFO - Calling model_fn.
# 2019-07-02 18:57:21,940 - tensorflow - INFO - Calling model_fn.
# 2019-07-02 18:57:22,477 - tensorflow - INFO - Done calling model_fn.
# 2019-07-02 18:57:22,479 - tensorflow - INFO - Create CheckpointSaverHook.
# 2019-07-02 18:57:22.488001: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:57:22.488038: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:57:22.505536: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:57:22.505576: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:57:22.545123: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:57:22.545161: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:57:22.561561: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:57:22.561598: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:57:22,895 - tensorflow - INFO - Done calling model_fn.
# 2019-07-02 18:57:22,897 - tensorflow - INFO - Create CheckpointSaverHook.
# 2019-07-02 18:57:22.925822: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:57:22.925867: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:57:22.964704: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:57:22.964741: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:57:23,450 - tensorflow - INFO - Graph was finalized.
# 2019-07-02 18:57:23,088 - tensorflow - INFO - Graph was finalized.
# ...
# 2019-07-02 18:58:42,961 - tensorflow - INFO - loss = 0.083959654, step = 7336 (3.993 sec)
# 2019-07-02 18:58:42,736 - tensorflow - INFO - global_step/sec: 94.7848
# 2019-07-02 18:58:43.238686: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:58:43.238730: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:58:43,520 - tensorflow - INFO - global_step/sec: 128.856
# 2019-07-02 18:58:43,729 - tensorflow - INFO - Calling model_fn.
# 2019-07-02 18:58:43,908 - tensorflow - INFO - Done calling model_fn.
# 2019-07-02 18:58:43,938 - tensorflow - INFO - Starting evaluation at 2019-07-02-18:58:43
# 2019-07-02 18:58:44,059 - tensorflow - INFO - Graph was finalized.
# 2019-07-02 18:58:44,131 - tensorflow - INFO - Restoring parameters from s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model/model.ckpt-7150
# 2019-07-02 18:58:44,395 - tensorflow - INFO - Running local_init_op.
# 2019-07-02 18:58:44,402 - tensorflow - INFO - Done running local_init_op.
# 2019-07-02 18:58:44,456 - tensorflow - INFO - Evaluation [1/10]
# 2019-07-02 18:58:44,472 - tensorflow - INFO - Evaluation [2/10]
# 2019-07-02 18:58:44,487 - tensorflow - INFO - Evaluation [3/10]
# 2019-07-02 18:58:43,867 - tensorflow - INFO - loss = 0.14749064, step = 7431 (4.191 sec)
# 2019-07-02 18:58:44,819 - tensorflow - INFO - global_step/sec: 91.6271
# 2019-07-02 18:58:44,502 - tensorflow - INFO - Evaluation [4/10]
# 2019-07-02 18:58:44,517 - tensorflow - INFO - Evaluation [5/10]
# 2019-07-02 18:58:44,531 - tensorflow - INFO - Evaluation [6/10]
# 2019-07-02 18:58:44,546 - tensorflow - INFO - Evaluation [7/10]
# 2019-07-02 18:58:44,560 - tensorflow - INFO - Evaluation [8/10]
# 2019-07-02 18:58:44,575 - tensorflow - INFO - Evaluation [9/10]
# 2019-07-02 18:58:44,591 - tensorflow - INFO - Evaluation [10/10]
# 2019-07-02 18:58:44,612 - tensorflow - INFO - Finished evaluation at 2019-07-02-18:58:44
# 2019-07-02 18:58:44,613 - tensorflow - INFO - Saving dict for global step 7155: accuracy = 0.975, global_step = 7155, loss = 0.10028534
# 2019-07-02 18:58:44,701 - tensorflow - INFO - Saving 'checkpoint_path' summary for global step 7155: s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model/model.ckpt-7150
# 2019-07-02 18:58:45,603 - tensorflow - INFO - global_step/sec: 137.672
# 2019-07-02 18:58:45,659 - tensorflow - INFO - loss = 0.19847085, step = 7638 (4.078 sec)
# 2019-07-02 18:58:45,723 - tensorflow - INFO - Saving checkpoints for 7656 into s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model/model.ckpt.
# 2019-07-02 18:58:46,615 - tensorflow - INFO - global_step/sec: 106.769
# 2019-07-02 18:58:47,913 - tensorflow - INFO - global_step/sec: 81.6276
# 2019-07-02 18:58:48.025217: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:58:48.025299: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:58:48,333 - tensorflow - INFO - Skip the current checkpoint eval due to throttle secs (10 secs).
# 2019-07-02 18:58:48,651 - tensorflow - INFO - global_step/sec: 144.95
# 2019-07-02 18:58:46,198 - tensorflow - INFO - loss = 0.17042437, step = 7702 (3.885 sec)
# 2019-07-02 18:58:47,193 - tensorflow - INFO - loss = 0.41967982, step = 7793 (4.232 sec)
# 2019-07-02 18:58:47,978 - tensorflow - INFO - loss = 0.22479671, step = 7855 (4.111 sec)
# 2019-07-02 18:58:49,523 - tensorflow - INFO - global_step/sec: 115.814
# 2019-07-02 18:58:49,927 - tensorflow - INFO - loss = 0.05930982, step = 8105 (4.268 sec)
# 2019-07-02 18:58:50,116 - tensorflow - INFO - loss = 0.15429987, step = 8119 (9.783 sec)
# 2019-07-02 18:58:50,365 - tensorflow - INFO - Saving checkpoints for 8161 into s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model/model.ckpt.
# 2019-07-02 18:58:50,240 - tensorflow - INFO - loss = 0.20079535, step = 8137 (4.042 sec)
# 2019-07-02 18:58:50,911 - tensorflow - INFO - loss = 0.07909021, step = 8226 (3.718 sec)
# 2019-07-02 18:58:50,489 - tensorflow - INFO - global_step/sec: 127.312
# 2019-07-02 18:58:51,709 - tensorflow - INFO - global_step/sec: 95.0997
# 2019-07-02 18:58:51,733 - tensorflow - INFO - loss = 0.25239187, step = 8296 (3.756 sec)
# 2019-07-02 18:58:52,776 - tensorflow - INFO - global_step/sec: 96.5953
# 2019-07-02 18:58:52.691138: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:58:52.691177: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:58:52,952 - tensorflow - INFO - Skip the current checkpoint eval due to throttle secs (10 secs).
# 2019-07-02 18:58:53,588 - tensorflow - INFO - global_step/sec: 128.012
# 2019-07-02 18:58:54,304 - tensorflow - INFO - loss = 0.06410249, step = 8582 (4.064 sec)
# 2019-07-02 18:58:54,945 - tensorflow - INFO - loss = 0.13471094, step = 8673 (4.034 sec)
# 2019-07-02 18:58:54,315 - tensorflow - INFO - loss = 0.1177061, step = 8583 (4.389 sec)
# 2019-07-02 18:58:54,432 - tensorflow - INFO - global_step/sec: 124.475
# 2019-07-02 18:58:54,877 - tensorflow - INFO - Saving checkpoints for 8667 into s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model/model.ckpt.
# 2019-07-02 18:58:55,286 - tensorflow - INFO - global_step/sec: 122.94
# 2019-07-02 18:58:56,335 - tensorflow - INFO - global_step/sec: 98.1418
# 2019-07-02 18:58:57.100388: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:58:57.100428: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:58:57,637 - tensorflow - INFO - global_step/sec: 97.5296
# 2019-07-02 18:58:57,809 - tensorflow - INFO - Calling model_fn.
# 2019-07-02 18:58:57,986 - tensorflow - INFO - Done calling model_fn.
# 2019-07-02 18:58:58,016 - tensorflow - INFO - Starting evaluation at 2019-07-02-18:58:58
# 2019-07-02 18:58:58,140 - tensorflow - INFO - Graph was finalized.
# 2019-07-02 18:58:58,241 - tensorflow - INFO - Restoring parameters from s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model/model.ckpt-8667
# 2019-07-02 18:58:57,948 - tensorflow - INFO - loss = 0.086749665, step = 8975 (3.643 sec)
# 2019-07-02 18:58:58,608 - tensorflow - INFO - global_step/sec: 103.056
# 2019-07-02 18:58:58,674 - tensorflow - INFO - loss = 0.06765793, step = 9045 (4.359 sec)
# 2019-07-02 18:58:58,739 - tensorflow - INFO - Running local_init_op.
# 2019-07-02 18:58:58,745 - tensorflow - INFO - Done running local_init_op.
# 2019-07-02 18:58:58,806 - tensorflow - INFO - Evaluation [1/10]
# 2019-07-02 18:58:58,828 - tensorflow - INFO - Evaluation [2/10]
# 2019-07-02 18:58:58,845 - tensorflow - INFO - Evaluation [3/10]
# 2019-07-02 18:58:58,860 - tensorflow - INFO - Evaluation [4/10]
# 2019-07-02 18:58:58,877 - tensorflow - INFO - Evaluation [5/10]
# 2019-07-02 18:58:58,903 - tensorflow - INFO - Evaluation [6/10]
# 2019-07-02 18:58:58,927 - tensorflow - INFO - Evaluation [7/10]
# 2019-07-02 18:58:58,946 - tensorflow - INFO - Evaluation [8/10]
# 2019-07-02 18:58:59,218 - tensorflow - INFO - Evaluation [9/10]
# 2019-07-02 18:58:59,235 - tensorflow - INFO - Evaluation [10/10]
# 2019-07-02 18:58:59,253 - tensorflow - INFO - Finished evaluation at 2019-07-02-18:58:59
# 2019-07-02 18:58:59,253 - tensorflow - INFO - Saving dict for global step 8670: accuracy = 0.9828125, global_step = 8670, loss = 0.050361134
# 2019-07-02 18:58:59,366 - tensorflow - INFO - Saving 'checkpoint_path' summary for global step 8670: s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model/model.ckpt-8667
# 2019-07-02 18:58:55,783 - tensorflow - INFO - loss = 0.039712176, step = 8762 (4.049 sec)
# 2019-07-02 18:58:59,427 - tensorflow - INFO - loss = 0.23454589, step = 9121 (3.644 sec)
# 2019-07-02 18:58:59,526 - tensorflow - INFO - loss = 0.104218215, step = 9138 (4.581 sec)
# 2019-07-02 18:58:59,552 - tensorflow - INFO - global_step/sec: 110.101
# 2019-07-02 18:58:59,723 - tensorflow - INFO - Saving checkpoints for 9169 into s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model/model.ckpt.
# 2019-07-02 18:59:00,622 - tensorflow - INFO - global_step/sec: 101.887
# 2019-07-02 18:59:01,727 - tensorflow - INFO - loss = 0.05827143, step = 9360 (3.779 sec)
# 2019-07-02 18:59:01,678 - tensorflow - INFO - global_step/sec: 96.6374
# 2019-07-02 18:59:02.260222: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:59:02.260274: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:59:01,979 - tensorflow - INFO - Loss for final step: 0.08380407.
# 2019-07-02 18:59:02,159 - tensorflow - INFO - Loss for final step: 0.20779562.
# 2019-07-02 18:59:02,057 - tensorflow - INFO - Loss for final step: 0.28052288.
# 2019-07-02 18:59:02,519 sagemaker_tensorflow_container.training INFO     master algo-1 is still up, waiting for it to exit
# 2019-07-02 18:59:02,395 - tensorflow - INFO - Loss for final step: 0.09744049.
# 2019-07-02 18:59:02,521 - tensorflow - INFO - Skip the current checkpoint eval due to throttle secs (10 secs).
# 2019-07-02 18:59:02,534 - tensorflow - INFO - Saving checkpoints for 9382 into s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model/model.ckpt.
# 2019-07-02 18:59:03,228 sagemaker_tensorflow_container.training INFO     master algo-1 is still up, waiting for it to exit
# 2019-07-02 18:59:03,049 sagemaker_tensorflow_container.training INFO     master algo-1 is still up, waiting for it to exit
# 2019-07-02 18:59:03,729 sagemaker_tensorflow_container.training INFO     master algo-1 is still up, waiting for it to exit
# 2019-07-02 18:59:04.808290: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2019-07-02 18:59:04.808329: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2019-07-02 18:59:05,041 - tensorflow - INFO - Skip the current checkpoint eval due to throttle secs (10 secs).
# 2019-07-02 18:59:05,196 - tensorflow - INFO - Calling model_fn.
# 2019-07-02 18:59:05,356 - tensorflow - INFO - Done calling model_fn.
# 2019-07-02 18:59:05,383 - tensorflow - INFO - Starting evaluation at 2019-07-02-18:59:05
# 2019-07-02 18:59:05,582 - tensorflow - INFO - Graph was finalized.
# 2019-07-02 18:59:05,670 - tensorflow - INFO - Restoring parameters from s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model/model.ckpt-9382
# 2019-07-02 18:59:05,861 - tensorflow - INFO - Running local_init_op.
# 2019-07-02 18:59:05,867 - tensorflow - INFO - Done running local_init_op.
# 2019-07-02 18:59:05,920 - tensorflow - INFO - Evaluation [1/10]
# 2019-07-02 18:59:05,934 - tensorflow - INFO - Evaluation [2/10]
# 2019-07-02 18:59:05,947 - tensorflow - INFO - Evaluation [3/10]
# 2019-07-02 18:59:05,960 - tensorflow - INFO - Evaluation [4/10]
# 2019-07-02 18:59:05,974 - tensorflow - INFO - Evaluation [5/10]
# 2019-07-02 18:59:05,987 - tensorflow - INFO - Evaluation [6/10]
# 2019-07-02 18:59:06,000 - tensorflow - INFO - Evaluation [7/10]
# 2019-07-02 18:59:06,013 - tensorflow - INFO - Evaluation [8/10]
# 2019-07-02 18:59:06,035 - tensorflow - INFO - Evaluation [9/10]
# 2019-07-02 18:59:06,051 - tensorflow - INFO - Evaluation [10/10]
# 2019-07-02 18:59:06,067 - tensorflow - INFO - Finished evaluation at 2019-07-02-18:59:06
# 2019-07-02 18:59:06,067 - tensorflow - INFO - Saving dict for global step 9382: accuracy = 0.98125, global_step = 9382, loss = 0.06302488
# 2019-07-02 18:59:06,311 - tensorflow - INFO - Saving 'checkpoint_path' summary for global step 9382: s3://com.climate.production.analytics/dsw/scratch/sagemaker/models/peta_sage_hack/20190702-184348/output/petastorm-sagemaker-2019-07-02-18-54-05-832/model/model.ckpt-9382
# 2019-07-02 18:59:06,387 - tensorflow - DEBUG - Calling exporter with the `is_the_final_export=True`.
# 2019-07-02 18:59:06,398 - tensorflow - INFO - Loss for final step: 0.13780728.
# 2019-07-02 18:59:07,058 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://github.com/aws/sagemaker-python-sdk/tree/master/src/sagemaker/tensorflow#adapting-your-local-tensorflow-script
# 2019-07-02 18:59:07,059 sagemaker-containers INFO     Reporting training SUCCESS
# 2019-07-02 19:00:20,556 sagemaker_tensorflow_container.training INFO     master algo-1 is down, stopping parameter server
# 2019-07-02 19:00:20,556 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://github.com/aws/sagemaker-python-sdk/tree/master/src/sagemaker/tensorflow#adapting-your-local-tensorflow-script
# 2019-07-02 19:00:20,556 sagemaker-containers INFO     Reporting training SUCCESS
# 2019-07-02 19:00:20,866 sagemaker_tensorflow_container.training INFO     master algo-1 is down, stopping parameter server
# 2019-07-02 19:00:20,867 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://github.com/aws/sagemaker-python-sdk/tree/master/src/sagemaker/tensorflow#adapting-your-local-tensorflow-script
# 2019-07-02 19:00:20,867 sagemaker-containers INFO     Reporting training SUCCESS
# 2019-07-02 19:00:21,251 sagemaker_tensorflow_container.training INFO     master algo-1 is down, stopping parameter server
# 2019-07-02 19:00:21,252 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://github.com/aws/sagemaker-python-sdk/tree/master/src/sagemaker/tensorflow#adapting-your-local-tensorflow-script
# 2019-07-02 19:00:21,252 sagemaker-containers INFO     Reporting training SUCCESS
# 2019-07-02 19:01:23,747 sagemaker_tensorflow_container.training INFO     master algo-1 is down, stopping parameter server
# 2019-07-02 19:01:23,747 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://github.com/aws/sagemaker-python-sdk/tree/master/src/sagemaker/tensorflow#adapting-your-local-tensorflow-script
# 2019-07-02 19:01:23,747 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2019-07-02 19:02:18 Uploading - Uploading generated training model
# 2019-07-02 19:02:18 Completed - Training job completed
# Billable seconds: 1850
# CPU times: user 1.59 s, sys: 121 ms, total: 1.71 s
# Wall time: 8min 24s

# %% [markdown]
# Final accuracy is 0.95ish as well - this time wall time = 8min and 24s.
